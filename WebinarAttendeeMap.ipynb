# %%
import pandas
import geopandas
import matplotlib as plt

# %%
# world map
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.plot();

# %%
# attendee data
attendees = pandas.read_csv(r"C:\Users\cif3\Downloads\Attended_processed.csv")
attendees.head()

country2_list = attendees['Country/Region']

# %%
# country codes (alpha2 and alpha3)
country_list = pandas.read_csv(r"C:\Users\cif3\Downloads\wikipedia-iso-country-codes.csv")
country_list.head()
# Out:
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                   Afghanistan           AF          AFG             4
# 1                 Åland Islands           AX          ALA           248
# 2                       Albania           AL          ALB             8
# 3                       Algeria           DZ          DZA            12
# 4                American Samoa           AS          ASM            16
#
#       ISO 3166-2
# 0  ISO 3166-2:AF
# 1  ISO 3166-2:AX
# 2  ISO 3166-2:AL
# 3  ISO 3166-2:DZ
# 4  ISO 3166-2:AS

# %%
# add coumtry from attendee list to new column in countrycodes 
for row in country_list:
    if row.contains(country2_list):
        print(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-efe8da227a42> in <module>
#       1 # add coumtry from attendee list to new column in countrycodes
#       2 for row in country_list:
# ----> 3     if row.str.contains(country2_list):
#       4         print(row)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
import csv

dic = {}
with open(r"C:\Users\cif3\Downloads\wikipedia-iso-country-codes.csv") as f:
    file= csv.DictReader(f, delimiter=',')
    for line in file:
        dic[line['English short name lower case']] = line['Alpha-2 code']       
        
#countries = ['American Samoa', 'Canada', 'France']

for country in country2_list:
    print(dic[country])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-9d6de0b84a4d> in <module>
#      10
#      11 for country in country2_list:
# ---> 12     print(dic[country])
#
# KeyError: 'US'

# %%
# Out:
# AS
# CA
# FR
